# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sexWork_df = pd.read_csv('../../data/raw/prepped_online_sex_work.csv')
sexWork_df.head()
# Out:
#    Unnamed: 0 Gender   Age  Verification Sexual_orientation Sexual_polarity  \
# 0           0   male  34,6  Non_Verified         Homosexual          Switch
# 1           1   male  32,2  Non_Verified       Heterosexual        Dominant
# 2           2   male  33,6  Non_Verified       Heterosexual        Dominant
# 3           3   male    34  Non_Verified       Heterosexual        Dominant
# 4           4   male  39,5  Non_Verified       Heterosexual        Dominant
#
#   Looking_for      Last_login Member_since  \
# 0         Men  before_10_days   2012-09-17
# 1       Women   before_1_days   2009-01-11
# 2       Women   before_3_days   2013-01-04
# 3       Women   before_4_days   2013-08-04
# 4       Women   before_5_days   2013-04-14
#
#    Number_of_Comments_in_public_forum Time_spent_chating_H:M  \
# 0                                  32                    0:2
# 1                                 710                   3:45
# ...

# %%
sexWork_df.drop(sexWork_df.columns[0:1], axis=1, inplace=True)
sexWork_df.head()
# Out:
#     Age  Verification Sexual_orientation Sexual_polarity Looking_for  \
# 0  34,6  Non_Verified         Homosexual          Switch         Men
# 1  32,2  Non_Verified       Heterosexual        Dominant       Women
# 2  33,6  Non_Verified       Heterosexual        Dominant       Women
# 3    34  Non_Verified       Heterosexual        Dominant       Women
# 4  39,5  Non_Verified       Heterosexual        Dominant       Women
#
#        Last_login Member_since  Number_of_Comments_in_public_forum  \
# 0  before_10_days   2012-09-17                                  32
# 1   before_1_days   2009-01-11                                 710
# 2   before_3_days   2013-01-04                                  25
# 3   before_4_days   2013-08-04                                 107
# 4   before_5_days   2013-04-14                                 600
#
#   Time_spent_chating_H:M  Number_of_offline_meetings_attended  \
# 0                    0:2                                  0.0
# ...

# %%
sexWork_df.groupby('Sexual_polarity')[['Friends']].mean()
# Out:
#                   Friends
# Sexual_polarity
# Dominant         3.223440
# Submisive        3.415574
# Switch           3.758454

# %%
sexWork_df.groupby('Sexual_polarity')[['Friends', 'Days', 'Profile_pictures', 'Number_of_Comments_in_public_forum', 'Number_of_offline_meetings_attended']].mean()
# Out:
#                   Friends      Days  Profile_pictures  \
# Sexual_polarity
# Dominant         3.223440  0.107736          0.422159
# Submisive        3.415574  0.140557          0.473002
# Switch           3.758454  0.169319          0.403504
#
#                  Number_of_Comments_in_public_forum  \
# Sexual_polarity
# Dominant                                   2.507736
# Submisive                                  2.768927
# Switch                                     2.191521
#
#                  Number_of_offline_meetings_attended
# Sexual_polarity
# Dominant                                    0.045845
# Submisive                                   0.035967
# Switch                                      0.045740

# %%
sexWork_df.groupby('Sexual_polarity').size()
# Out:
# Sexual_polarity
# Dominant     10470
# Submisive    10871
# Switch        7477
# dtype: int64
