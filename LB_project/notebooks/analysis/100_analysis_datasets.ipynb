# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sexWork_df = pd.read_csv('../../data/raw/prepped_online_sex_work.csv')
sexWork_df.head()
# Out:
#    Unnamed: 0 Gender   Age  Verification Sexual_orientation Sexual_polarity  \
# 0           0   male  34,6  Non_Verified         Homosexual          Switch
# 1           1   male  32,2  Non_Verified       Heterosexual        Dominant
# 2           2   male  33,6  Non_Verified       Heterosexual        Dominant
# 3           3   male    34  Non_Verified       Heterosexual        Dominant
# 4           4   male  39,5  Non_Verified       Heterosexual        Dominant
#
#   Looking_for Points_Rank      Last_login Member_since  \
# 0         Men          50  before_10_days   2012-09-17
# 1       Women         518   before_1_days   2009-01-11
# 2       Women         150   before_3_days   2013-01-04
# 3       Women         114   before_4_days   2013-08-04
# 4       Women         497   before_5_days   2013-04-14
#
#   Number_of_Comments_in_public_forum Time_spent_chating_H:M  \
# 0                                 32                    0:2
# ...

# %%
sexWork_df.drop(sexWork_df.columns[0:1], axis=1, inplace=True)
sexWork_df.head()
# Out:
#   Gender   Age  Verification Sexual_orientation Sexual_polarity Looking_for  \
# 0   male  34,6  Non_Verified         Homosexual          Switch         Men
# 1   male  32,2  Non_Verified       Heterosexual        Dominant       Women
# 2   male  33,6  Non_Verified       Heterosexual        Dominant       Women
# 3   male    34  Non_Verified       Heterosexual        Dominant       Women
# 4   male  39,5  Non_Verified       Heterosexual        Dominant       Women
#
#   Points_Rank      Last_login Member_since Number_of_Comments_in_public_forum  \
# 0          50  before_10_days   2012-09-17                                 32
# 1         518   before_1_days   2009-01-11                                710
# 2         150   before_3_days   2013-01-04                                 25
# 3         114   before_4_days   2013-08-04                                107
# 4         497   before_5_days   2013-04-14                                600
#
# ...

# %%
# sexWork_df.groupby(['Sexual_polarity', 'Friends'])['Friends'].count()
sexWork_df.groupby(['Sexual_polarity','Friends']).size().reset_index().groupby('Sexual_polarity').()
# Out:
#                  Friends   0
# Sexual_polarity
# Dominant              34  34
# Submisive             39  39
# Switch                29  29
