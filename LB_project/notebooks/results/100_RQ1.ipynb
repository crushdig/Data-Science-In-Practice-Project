# %% [markdown]
# # 100_RQ1 – Are dominant people more active and friendly online?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
results_sexWork_df = pd.read_csv('../../data/raw/prepped_online_sex_work.csv')
results_sexWork_df.head()
# Out:
#   Gender   Age  Verification Sexual_orientation Sexual_polarity Looking_for  \
# 0   male  34.6  Non_Verified         Homosexual          Switch         Men
# 1   male  32.2  Non_Verified       Heterosexual        Dominant       Women
# 2   male  33.6  Non_Verified       Heterosexual        Dominant       Women
# 3   male  34.0  Non_Verified       Heterosexual        Dominant       Women
# 4   male  39.5  Non_Verified       Heterosexual        Dominant       Women
#
#        Last_login Member_since  Number_of_Comments_in_public_forum  \
# 0  before_10_days   2012-09-17                                  32
# 1   before_1_days   2009-01-11                                 710
# 2   before_3_days   2013-01-04                                  25
# 3   before_4_days   2013-08-04                                 107
# 4   before_5_days   2013-04-14                                 600
#
#    Number_of_offline_meetings_attended  Profile_pictures     Risk  Days  \
# ...

# %%
results_sexWork_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28819 entries, 0 to 28818
# Data columns (total 15 columns):
# Gender                                 28815 non-null object
# Age                                    28813 non-null float64
# Verification                           28819 non-null object
# Sexual_orientation                     28818 non-null object
# Sexual_polarity                        28818 non-null object
# Looking_for                            28395 non-null object
# Last_login                             28819 non-null object
# Member_since                           28819 non-null object
# Number_of_Comments_in_public_forum     28819 non-null int64
# Number_of_offline_meetings_attended    28819 non-null float64
# Profile_pictures                       28819 non-null float64
# Risk                                   28819 non-null object
# Days                                   28819 non-null int64
# Total_chat_time                        28819 non-null object
# ...

# %%
results_sexWork_df['Total_chat_time'] = pd.to_timedelta(results_sexWork_df['Total_chat_time'])

# %%
results_sexWork_df.head()
# Out:
#   Gender   Age  Verification Sexual_orientation Sexual_polarity Looking_for  \
# 0   male  34.6  Non_Verified         Homosexual          Switch         Men
# 1   male  32.2  Non_Verified       Heterosexual        Dominant       Women
# 2   male  33.6  Non_Verified       Heterosexual        Dominant       Women
# 3   male  34.0  Non_Verified       Heterosexual        Dominant       Women
# 4   male  39.5  Non_Verified       Heterosexual        Dominant       Women
#
#        Last_login Member_since  Number_of_Comments_in_public_forum  \
# 0  before_10_days   2012-09-17                                  32
# 1   before_1_days   2009-01-11                                 710
# 2   before_3_days   2013-01-04                                  25
# 3   before_4_days   2013-08-04                                 107
# 4   before_5_days   2013-04-14                                 600
#
#    Number_of_offline_meetings_attended  Profile_pictures     Risk  Days  \
# ...

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

friend_count = results_sexWork_df.groupby(['Gender', 'Sexual_polarity'])['Friends'].mean()
friend_count = friend_count.unstack()
friend_count_graph = friend_count.plot(kind='bar', figsize=(15, 9), rot=0, fontsize=18, color=colours)

friend_count_graph.set_title('Average Number of Online Friends Based on Sexual Polarity and Gender', fontsize=24)
friend_count_graph.set_xlabel('Gender', fontsize=18)
friend_count_graph.set_ylabel('Average Number of Friends', fontsize=18)
friend_count_graph.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-d57bb6926d56> in <module>()
#      13    markerscale=1.5,
#      14    fontsize=15)
# ---> 15 friend_count_graph.add_subplot(112)
#
# AttributeError: 'AxesSubplot' object has no attribute 'add_subplot'

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

comment_count = results_sexWork_df.groupby(['Gender', 'Sexual_polarity'])['Number_of_Comments_in_public_forum'].mean()
comment_count = comment_count.unstack()
comment_count_graph = comment_count.plot(kind='bar', figsize=(15, 9), rot=0, fontsize=18, color=colours)

comment_count_graph.set_title('Average Number of Comments Posted Based on Sexual Polarity and Gender', fontsize=24)
comment_count_graph.set_xlabel('Gender', fontsize=18)
comment_count_graph.set_ylabel('Average Number of Comments', fontsize=18)
comment_count_graph.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
# Two subplots, the axes array is 1-d
f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(friend_count, comment_count)
axarr[0].set_title('Sharing X axis')
axarr[1].scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-43e90e60d373> in <module>()
#       1 # Two subplots, the axes array is 1-d
#       2 f, axarr = plt.subplots(2, sharex=True)
# ----> 3 axarr[0].plot(friend_count, comment_count)
#       4 axarr[0].set_title('Sharing X axis')
#       5 axarr[1].scatter(x, y)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1843                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1844                         RuntimeWarning, stacklevel=2)
# -> 1845             return func(ax, *args, **kwargs)
#    1846
#    1847         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1523         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1524
# ...

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

picture_count = results_sexWork_df.groupby(['Gender', 'Sexual_polarity'])['Profile_pictures'].mean()
picture_count = picture_count.unstack()
picture_count_graph = picture_count.plot(kind='bar', figsize=(15, 9), rot=0, fontsize=18, color=colours)

picture_count_graph.set_title('Average Number of Profile Pictures Based on Sexual Polarity and Gender', fontsize=24)
picture_count_graph.set_xlabel('Gender', fontsize=18)
picture_count_graph.set_ylabel('Average Number of Profile Pictures', fontsize=18)
picture_count_graph.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

meetings_count = results_sexWork_df.groupby(['Gender', 'Sexual_polarity'])['Number_of_offline_meetings_attended'].mean()
meetings_count = meetings_count.unstack()
meetings_count_graph = meetings_count.plot(kind='bar', figsize=(15, 9), rot=0, fontsize=18, color=colours)

meetings_count_graph.set_title('Average Number of Offline Meetings Based on Sexual Polarity and Gender', fontsize=24)
meetings_count_graph.set_xlabel('Gender', fontsize=18)
meetings_count_graph.set_ylabel('Average Number of Offline Meetings', fontsize=18)
meetings_count_graph.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

friend_count = results_sexWork_df.groupby('Sexual_polarity')[['Friends']].mean()
friend_count_graph = friend_count.plot(kind='pie', figsize=(11, 11), rot=0, fontsize=20, subplots=True, autopct='%.2f', colors=colours)

plt.axis('equal')
plt.title('Percentage of Average Friend Count', fontsize=20)
plt.ylabel('', fontsize=14)

plt.legend(
   labels=friend_count.index,
   loc='upper left',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

plt.show()

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

#chat_time = results_sexWork_df.groupby(['Sexual_polarity'])[['Total_chat_time']].sum() / results_sexWork_df.groupby(['Sexual_polarity'])[['Total_chat_time']].count()
#chat_time = results_sexWork_df['Total_chat_time']
#chat_time_graph = chat_time.plot(kind='line', figsize=(11, 11), rot=0, fontsize=20, subplots=True, color=colours)
results_sexWork_df['Total_chat_time'].plot

plt.axis('equal')
plt.title('Percentage of Average Friend Count', fontsize=20)
plt.ylabel('', fontsize=14)

plt.legend(
   labels=chat_time.index,
   loc='upper left',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

plt.show()

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

friends_age = results_sexWork_df.groupby(['Age'])[['Friends']].count()
friends_age = friends_age.unstack()
friends_age_graph = friends_age.plot(kind='line', figsize=(15, 9), rot=0, fontsize=18, color=colours)

friends_age_graph.set_title('Average Number of Offline Meetings Based on Sexual Polarity and Gender', fontsize=24)
friends_age_graph.set_xlabel('Gender', fontsize=18)
friends_age_graph.set_ylabel('Average Number of Offline Meetings', fontsize=18)
friends_age_graph.set_xticklabels(results_sexWork_df['Age'])

friends_age_graph.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)
