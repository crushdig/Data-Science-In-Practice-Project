# %% [markdown]
# # 100_RQ1 – Are dominant people more active and friendly online?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
results_sexWork_df = pd.read_csv('../../data/raw/prepped_online_sex_work.csv')
results_sexWork_df.head()
# Out:
#   Gender   Age  Verification Sexual_orientation Sexual_polarity Looking_for  \
# 0   male  34.6  Non_Verified         Homosexual          Switch         Men
# 1   male  32.2  Non_Verified       Heterosexual        Dominant       Women
# 2   male  33.6  Non_Verified       Heterosexual        Dominant       Women
# 3   male  34.0  Non_Verified       Heterosexual        Dominant       Women
# 4   male  39.5  Non_Verified       Heterosexual        Dominant       Women
#
#        Last_login Member_since  Number_of_Comments_in_public_forum  \
# 0  before_10_days   2012-09-17                                  32
# 1   before_1_days   2009-01-11                                 710
# 2   before_3_days   2013-01-04                                  25
# 3   before_4_days   2013-08-04                                 107
# 4   before_5_days   2013-04-14                                 600
#
#    Number_of_offline_meetings_attended  Profile_pictures     Risk  Days  \
# 0                                  0.0               0.0  No_risk     0
# 1                                  0.0               0.0  No_risk     0
# 2                                  1.0              45.0  No_risk     0
# 3                                  0.0               1.0  No_risk    14
# 4                                  6.0               8.0  No_risk     0
#
#              Total_chat_time  Friends
# 0  0 days 00:02:00.000000000      1.0
# 1  0 days 03:45:00.000000000      7.0
# 2  0 days 02:15:00.000000000      3.0
# 3  0 days 23:22:00.000000000     12.0
# 4  0 days 00:21:00.000000000     35.0

# %%
results_sexWork_df['Total_chat_time'] = pd.to_timedelta(results_sexWork_df['Total_chat_time'])

# %%
results_sexWork_df.head()
# Out:
#   Gender   Age  Verification Sexual_orientation Sexual_polarity Looking_for  \
# 0   male  34.6  Non_Verified         Homosexual          Switch         Men
# 1   male  32.2  Non_Verified       Heterosexual        Dominant       Women
# 2   male  33.6  Non_Verified       Heterosexual        Dominant       Women
# 3   male  34.0  Non_Verified       Heterosexual        Dominant       Women
# 4   male  39.5  Non_Verified       Heterosexual        Dominant       Women
#
#        Last_login Member_since  Number_of_Comments_in_public_forum  \
# 0  before_10_days   2012-09-17                                  32
# 1   before_1_days   2009-01-11                                 710
# 2   before_3_days   2013-01-04                                  25
# 3   before_4_days   2013-08-04                                 107
# 4   before_5_days   2013-04-14                                 600
#
#    Number_of_offline_meetings_attended  Profile_pictures     Risk  Days  \
# 0                                  0.0               0.0  No_risk     0
# 1                                  0.0               0.0  No_risk     0
# 2                                  1.0              45.0  No_risk     0
# 3                                  0.0               1.0  No_risk    14
# 4                                  6.0               8.0  No_risk     0
#
#   Total_chat_time  Friends
# 0        00:02:00      1.0
# 1        03:45:00      7.0
# 2        02:15:00      3.0
# 3        23:22:00     12.0
# 4        00:21:00     35.0

# %%
#colours = ['#75ECFD', '#FFFF66', '#95FF4F']

friend_count = results_sexWork_df.groupby('Sexual_polarity')[['Friends']].mean()
friend_count_graph = friend_count.plot(kind='bar', figsize=(15, 11), rot=0, fontsize=18, color='#fc913a')
friend_count_graph.set_xlabel('Sexual Polarity', fontsize=18)
friend_count_graph.set_ylabel('Average Number of Friends', fontsize=18)
friend_count_graph.legend(
   labels=friend_count.index,
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

friend_count = results_sexWork_df.groupby('Sexual_polarity')[['Friends']].mean()
friend_count_graph = friend_count.plot(kind='pie', figsize=(11, 11), rot=0, fontsize=20, subplots=True, autopct='%.2f', colors=colours)

plt.axis('equal')
plt.title('Percentage of Average Friend Count', fontsize=20)
plt.ylabel('', fontsize=14)

plt.legend(
   labels=friend_count.index,
   loc='upper left',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

plt.show()

# %%
colours = ['#75ECFD', '#FFFF66', '#95FF4F']

chat_time = results_sexWork_df.groupby(['Sexual_polarity'])[['Total_chat_time']].sum() / results_sexWork_df.groupby(['Sexual_polarity'])[['Total_chat_time']].count()
chat_time_graph = chat_time.plot(kind='scatter', figsize=(11, 11), rot=0, fontsize=20, subplots=True, autopct='%.2f', colors=colours)

plt.axis('equal')
plt.title('Percentage of Average Friend Count', fontsize=20)
plt.ylabel('', fontsize=14)

plt.legend(
   labels=chat_time.index,
   loc='upper left',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

plt.show()
# Out:
# /Users/lilahrose/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:179: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-f3bc18f6b5a3> in <module>()
#       2
#       3 chat_time = results_sexWork_df.groupby(['Sexual_polarity'])[['Total_chat_time']].sum() / results_sexWork_df.groupby(['Sexual_polarity'])[['Total_chat_time']].count()
# ----> 4 chat_time_graph = chat_time.plot(kind='scatter', figsize=(11, 11), rot=0, fontsize=20, subplots=True, autopct='%.2f', colors=colours)
#       5
#       6 plt.axis('equal')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1650         if isinstance(data, DataFrame):
#    1651             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1652                              kind=kind, **kwds)
#    1653         else:
#    1654             raise ValueError("plot kind %r can only be used for data frames"
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     808             # the handling of this argument later
#     809             s = 20
# --> 810         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     811         if is_integer(c) and not self.data.columns.holds_integer():
#     812             c = self.data.columns[c]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, **kwargs)
#     777         MPLPlot.__init__(self, data, **kwargs)
#     778         if x is None or y is None:
# --> 779             raise ValueError(self._kind + ' requires and x and y column')
#     780         if is_integer(x) and not self.data.columns.holds_integer():
#     781             x = self.data.columns[x]
#
# ValueError: scatter requires and x and y column
