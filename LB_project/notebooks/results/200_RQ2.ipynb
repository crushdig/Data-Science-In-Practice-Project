# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# import plotly.plotly as py
# import plotly.graph_objs as go
# from plotly.graph_objs import *

# %%
results_redditThread_df = pd.read_csv('../../data/raw/prepped_foreveralone.csv')
results_redditThread_df.head()
# Out:
#   gender sexuality  age                race     bodyweight virgin  \
# 0   Male  Straight   35  White non-Hispanic  Normal weight    Yes
# 1   Male  Bisexual   21  White non-Hispanic    Underweight    Yes
# 2   Male  Straight   22  White non-Hispanic     Overweight    Yes
# 3   Male  Straight   19  White non-Hispanic     Overweight    Yes
# 4   Male  Straight   23  White non-Hispanic     Overweight     No
#
#   prostitution_legal     pay_for_sex  friends social_fear  \
# 0                 No              No        0         Yes
# 1                 No              No        0         Yes
# 2                 No              No       10         Yes
# 3                Yes              No        8         Yes
# 4                 No  Yes and I have       10          No
#
#                                            edu_level
# 0                                   Associate degree
# 1                            Some college, no degree
# 2                            Some college, no degree
# ...

# %%
colours = ['#CD919E', '#A52A2A', '#BDFCC9', '#6CA6CD']

sex_and_wellbeing = results_redditThread_df.groupby(['prostitution_legal'])[['bodyweight']].apply(lambda x: pd.DataFrame(x['bodyweight'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing = sex_and_wellbeing.plot(kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing.set_title('Number of People who would Legalise Prostitution based on Bodyweight', fontsize=24)
graph_sex_and_wellbeing.set_xlabel('Legalise Prostitution', fontsize=21)
graph_sex_and_wellbeing.set_ylabel('Number of People with Certain Weight', fontsize=21)
graph_sex_and_wellbeing.legend(
['Normal Weight', 'Obese', 'Overweight', 'Underweight'],
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
colours = ['#ffff00', '#9400d3']

sex_and_wellbeing = results_redditThread_df.groupby(['prostitution_legal'])[['social_fear']].apply(lambda x: pd.DataFrame(x['social_fear'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing1 = sex_and_wellbeing.plot(kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing1.set_title('Number of People who would Legalise Prostitution based on Social Fear', fontsize=24)
graph_sex_and_wellbeing1.set_xlabel('Legalise Prostitution', fontsize=21)
graph_sex_and_wellbeing1.set_ylabel('Social Fear Count', fontsize=21)
graph_sex_and_wellbeing1.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
colours = ['#722f37', '#C5B358']

sex_and_wellbeing = results_redditThread_df.groupby(['pay_for_sex'])[['social_fear']].apply(lambda x: pd.DataFrame(x['social_fear'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing2 = sex_and_wellbeing.plot(kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing2.set_title('Number of People who would Pay for Sex based on Social Fear', fontsize=24)
graph_sex_and_wellbeing2.set_xlabel('Sex payments', fontsize=21)
graph_sex_and_wellbeing2.set_ylabel('Social Fear Count', fontsize=21)
graph_sex_and_wellbeing2.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
colours = ['#F5DEB3', '#528B8B', '#9E9E9E', '#FFA500']

sex_and_wellbeing = results_redditThread_df.groupby(['pay_for_sex'])[['bodyweight']].apply(lambda x: pd.DataFrame(x['bodyweight'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing3 = sex_and_wellbeing.plot(kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing3.set_title('Number of People who would Pay for Sex based on Bodyweight', fontsize=24)
graph_sex_and_wellbeing3.set_xlabel('Sex payments', fontsize=21)
graph_sex_and_wellbeing3.set_ylabel('Number of People with Certain Weight', fontsize=21)
graph_sex_and_wellbeing3.legend(
    ['Normal Weight', 'Obese', 'Overweight', 'Underweight'],
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

colours = ['#CD919E', '#A52A2A', '#BDFCC9', '#6CA6CD']

sex_and_wellbeing = results_redditThread_df.groupby(['prostitution_legal'])[['bodyweight']].apply(lambda x: pd.DataFrame(x['bodyweight'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing = sex_and_wellbeing.plot(ax=axes[0,0], kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing.title.set_text('Number of People who would Legalise Prostitution based on Bodyweight')
graph_sex_and_wellbeing.set_xlabel('Legalise Prostitution', fontsize=21)
graph_sex_and_wellbeing.set_ylabel('Number of People with Certain Weight', fontsize=21)
graph_sex_and_wellbeing.legend(
['Normal Weight', 'Obese', 'Overweight', 'Underweight'],
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)


colours = ['#ffff00', '#9400d3']

sex_and_wellbeing = results_redditThread_df.groupby(['prostitution_legal'])[['social_fear']].apply(lambda x: pd.DataFrame(x['social_fear'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing1 = sex_and_wellbeing.plot(ax=axes[0,1], kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing1.title.set_text('Number of People who would Legalise Prostitution based on Social Fear')
graph_sex_and_wellbeing1.set_xlabel('Legalise Prostitution', fontsize=21)
graph_sex_and_wellbeing1.set_ylabel('Social Fear Count', fontsize=21)
graph_sex_and_wellbeing1.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)


colours = ['#722f37', '#C5B358']

sex_and_wellbeing = results_redditThread_df.groupby(['pay_for_sex'])[['social_fear']].apply(lambda x: pd.DataFrame(x['social_fear'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing2 = sex_and_wellbeing.plot(ax=axes[1,0], kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing2.title.set_text('Number of People who would Pay for Sex based on Social Fear')
graph_sex_and_wellbeing2.set_xlabel('Sex payments', fontsize=21)
graph_sex_and_wellbeing2.set_ylabel('Social Fear Count', fontsize=21)
graph_sex_and_wellbeing2.legend(
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

colours = ['#F5DEB3', '#528B8B', '#9E9E9E', '#FFA500']

sex_and_wellbeing = results_redditThread_df.groupby(['pay_for_sex'])[['bodyweight']].apply(lambda x: pd.DataFrame(x['bodyweight'].value_counts()))

sex_and_wellbeing = sex_and_wellbeing.unstack()
graph_sex_and_wellbeing3 = sex_and_wellbeing.plot(ax=axes[1,1], kind='bar', figsize=(20, 13), color=colours, rot=0, fontsize=21)

graph_sex_and_wellbeing3.title.set_text('Number of People who would Pay for Sex based on Bodyweight')
graph_sex_and_wellbeing3.set_xlabel('Sex payments', fontsize=21)
graph_sex_and_wellbeing3.set_ylabel('Number of People with Certain Weight', fontsize=21)
graph_sex_and_wellbeing3.legend(
    ['Normal Weight', 'Obese', 'Overweight', 'Underweight'],
   loc='best',
   ncol=1,
   markerscale=1.5,
   fontsize=15)

plt.tight_layout()
